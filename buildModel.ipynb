# %%
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
#custom Attentio layer
import tensorflow as tf
from tensorflow.python.keras import backend as K

logger = tf.get_logger()

class AttentionLayer(tf.keras.layers.Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs

        logger.debug(f"encoder_out_seq.shape = {encoder_out_seq.shape}")
        logger.debug(f"decoder_out_seq.shape = {decoder_out_seq.shape}")

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            logger.debug("Running energy computation step")

            if not isinstance(states, (list, tuple)):
                raise TypeError(f"States must be an iterable. Got {states} of type {type(states)}")

            encoder_full_seq = states[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_full_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim

            logger.debug(f"U_a_dot_h.shape = {U_a_dot_h.shape}")

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)

            logger.debug(f"Ws_plus_Uh.shape = {Ws_plus_Uh.shape}")

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            logger.debug(f"ei.shape = {e_i.shape}")

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            logger.debug("Running attention vector computation step")

            if not isinstance(states, (list, tuple)):
                raise TypeError(f"States must be an iterable. Got {states} of type {type(states)}")

            encoder_full_seq = states[-1]

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_full_seq * K.expand_dims(inputs, -1), axis=1)

            logger.debug(f"ci.shape = {c_i.shape}")

            return c_i, [c_i]

        # we don't maintain states between steps when computing attention
        # attention is stateless, so we're passing a fake state for RNN step function
        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e], constants=[encoder_out_seq]
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c], constants=[encoder_out_seq]
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
reviews = pd.read_csv('./Reviews.csv',nrows=10000)
reviews.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
reviews.drop_duplicates(subset=['Text'],inplace=True)
reviews.dropna(axis=0,inplace=True)

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

# %%
import string
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Sobhyzz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def text_cleaner(text):
    #to lower
    newString = text.lower()
    #xml parsing
    newString = BeautifulSoup(newString, "lxml").text

    #remove brackets
    newString = re.sub(r'\([^)]*\)', '', newString)

    #removing quotation
    newString = re.sub('"','', newString)
    
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])
    newString = re.sub(r"'s\b","",newString)

    #Eliminate non letters
    newString = re.sub("[^a-zA-Z]", " ", newString)

    #remove stop words
    tokens = [w for w in newString.split() if not w in stop_words]

    #remove short words
    long_words=[]
    for i in tokens:
        if len(i)>=3:
            long_words.append(i)
    return (" ".join(long_words)).strip()

# %%
cleaned_text = []
print(reviews['Text'][0])
for t in reviews['Text']:
    cleaned_text.append(text_cleaner(t))
cleaned_text[0]
# Out:
# I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
# /var/folders/vv/jrr00v852xj6f_6pp777r9zw0000gp/T/ipykernel_10559/808146248.py:5: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   newString = BeautifulSoup(newString, "lxml").text
# 'bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better'

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:
            newString=newString+i+' '
    return newString

#Call the above function
cleaned_summary = []
print(reviews['Summary'][0])
for t in reviews['Summary']:
    cleaned_summary.append(summary_cleaner(t))
print(cleaned_summary[0])
reviews['cleaned_text']=cleaned_text
reviews['cleaned_summary']=cleaned_summary
reviews['cleaned_summary'].replace('', np.nan, inplace=True)
reviews.dropna(axis=0,inplace=True)
# Out:
# Good Quality Dog Food
# good quality dog food
# /var/folders/vv/jrr00v852xj6f_6pp777r9zw0000gp/T/ipykernel_10559/1163459163.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   reviews['cleaned_summary'].replace('', np.nan, inplace=True)

# %%
reviews['cleaned_summary'] = reviews['cleaned_summary'].apply(lambda x : '<START> '+ x + ' <END>')

# %%
for i in range(5):
    print("Review:",reviews['cleaned_text'][i])
    print("Summary:",reviews['cleaned_summary'][i])
    print("\n")
# Out:
# Review: bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# Summary: <START> good quality dog food  <END>
#
#
# Review: product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# Summary: <START> not as advertised  <END>
#
#
# Review: confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
# Summary: <START> delight says it all  <END>
#
#
# Review: looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# Summary: <START> cough medicine  <END>
#
#
# Review: great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# Summary: <START> great taffy  <END>

# %%
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in reviews['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in reviews['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})
length_df.hist(bins=30)
# Out:
# array([[<Axes: title={'center': 'text'}>,
#         <Axes: title={'center': 'summary'}>]], dtype=object)

# %%
max_len_text, max_len_summary = 30, 8

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val = train_test_split(reviews['cleaned_text'],reviews['cleaned_summary'],test_size=0.1,random_state=0)

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr    =   x_tokenizer.texts_to_sequences(x_tr)
x_val   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr,  maxlen=max_len_text, padding='post')
x_val   =   pad_sequences(x_val, maxlen=max_len_text, padding='post')

x_voc_size   =  len(x_tokenizer.word_index) +1

# %%
#preparing a tokenizer for summary on training data
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

#convert summary sequences into integer sequences
y_tr    =   y_tokenizer.texts_to_sequences(y_tr)
y_val   =   y_tokenizer.texts_to_sequences(y_val)

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val   =   pad_sequences(y_val, maxlen=max_len_summary, padding='post')

y_voc_size  =   len(y_tokenizer.word_index) +1

# %%
latent_dim =300
encoder_inputs = Input(shape=(max_len_text,))
enc_emb = Embedding(x_voc_size, latent_dim,trainable=True)(encoder_inputs)

encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

encoder_lstm3 = LSTM(latent_dim,return_sequences=True,return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2)


decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(y_voc_size, latent_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 30)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 30, 300)   │  5,073,000 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 30, 300), │    721,200 │ embedding[0][0]   │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 30, 300), │    721,200 │ lstm[0][0]        │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 300) │  1,275,000 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 30, 300), │    721,200 │ lstm_1[0][0]      │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    721,200 │ embedding_1[0][0… │
# │                     │ 300), (None,      │            │ lstm_2[0][1],     │
# │                     │ 300), (None,      │            │ lstm_2[0][2]      │
# │                     │ 300)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_layer     │ [(None, None,     │    180,300 │ lstm_2[0][0],     │
# │ (AttentionLayer)    │ 300), (None,      │            │ lstm_3[0][0]      │
# │                     │ None, 30)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_layer        │ (None, None, 600) │          0 │ lstm_3[0][0],     │
# │ (Concatenate)       │                   │            │ attention_layer[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, None,      │  2,554,250 │ concat_layer[0][… │
# │ (TimeDistributed)   │ 4250)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,967,350 (45.65 MB)
#  Trainable params: 11,967,350 (45.65 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=150, batch_size=128, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 733ms/step - loss: 5.5431 - val_loss: 3.6897
# Epoch 2/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 726ms/step - loss: 3.5610 - val_loss: 3.5740
# Epoch 3/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 711ms/step - loss: 3.4591 - val_loss: 3.5405
# Epoch 4/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 714ms/step - loss: 3.3189 - val_loss: 3.5146
# Epoch 5/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 707ms/step - loss: 3.1929 - val_loss: 3.5124
# Epoch 6/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 711ms/step - loss: 3.1473 - val_loss: 3.5071
# Epoch 7/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - loss: 3.0683 - val_loss: 3.4995
# Epoch 8/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 493ms/step - loss: 3.0142 - val_loss: 3.4861
# Epoch 9/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 492ms/step - loss: 2.9157 - val_loss: 3.4824
# Epoch 10/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 502ms/step - loss: 2.8650 - val_loss: 3.4810
# Epoch 11/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 508ms/step - loss: 2.7817 - val_loss: 3.4654
# Epoch 12/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 495ms/step - loss: 2.7119 - val_loss: 3.4687
# Epoch 13/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 496ms/step - loss: 2.6480 - val_loss: 3.4741
# Epoch 14/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 504ms/step - loss: 2.6097 - val_loss: 3.4847
# Epoch 15/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 504ms/step - loss: 2.5190 - val_loss: 3.4966
# Epoch 16/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 512ms/step - loss: 2.4291 - val_loss: 3.5184
# Epoch 17/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 511ms/step - loss: 2.3639 - val_loss: 3.5308
# Epoch 18/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 502ms/step - loss: 2.2871 - val_loss: 3.5736
# Epoch 19/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 499ms/step - loss: 2.1975 - val_loss: 3.5768
# Epoch 20/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 31s 582ms/step - loss: 2.1242 - val_loss: 3.6173
# Epoch 21/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 707ms/step - loss: 2.0672 - val_loss: 3.6347
# Epoch 22/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 716ms/step - loss: 1.9733 - val_loss: 3.6639
# Epoch 23/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 723ms/step - loss: 1.8846 - val_loss: 3.7118
# Epoch 24/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 712ms/step - loss: 1.8032 - val_loss: 3.7455
# Epoch 25/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 714ms/step - loss: 1.7282 - val_loss: 3.7759
# Epoch 26/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 725ms/step - loss: 1.6240 - val_loss: 3.8240
# Epoch 27/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 718ms/step - loss: 1.5402 - val_loss: 3.8505
# Epoch 28/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 706ms/step - loss: 1.4570 - val_loss: 3.8892
# Epoch 29/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 707ms/step - loss: 1.3800 - val_loss: 3.9338
# Epoch 30/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 705ms/step - loss: 1.2765 - val_loss: 3.9880
# Epoch 31/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 712ms/step - loss: 1.2226 - val_loss: 4.0123
# Epoch 32/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 697ms/step - loss: 1.1525 - val_loss: 4.0522
# Epoch 33/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 701ms/step - loss: 1.0723 - val_loss: 4.0819
# Epoch 34/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 707ms/step - loss: 1.0078 - val_loss: 4.1376
# Epoch 35/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - loss: 0.9373 - val_loss: 4.1628
# Epoch 36/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 491ms/step - loss: 0.8724 - val_loss: 4.1943
# Epoch 37/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 496ms/step - loss: 0.8316 - val_loss: 4.2377
# Epoch 38/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 490ms/step - loss: 0.7620 - val_loss: 4.2627
# Epoch 39/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 487ms/step - loss: 0.7178 - val_loss: 4.3273
# Epoch 40/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 484ms/step - loss: 0.6596 - val_loss: 4.3763
# Epoch 41/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 483ms/step - loss: 0.6150 - val_loss: 4.3939
# Epoch 42/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 482ms/step - loss: 0.5787 - val_loss: 4.4476
# Epoch 43/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 475ms/step - loss: 0.5277 - val_loss: 4.4641
# Epoch 44/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 482ms/step - loss: 0.4896 - val_loss: 4.5185
# Epoch 45/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 490ms/step - loss: 0.4442 - val_loss: 4.5437
# Epoch 46/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 489ms/step - loss: 0.4108 - val_loss: 4.5685
# Epoch 47/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 498ms/step - loss: 0.3735 - val_loss: 4.6103
# Epoch 48/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 499ms/step - loss: 0.3444 - val_loss: 4.6747
# Epoch 49/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 492ms/step - loss: 0.3158 - val_loss: 4.6946
# Epoch 50/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 487ms/step - loss: 0.2796 - val_loss: 4.7441
# Epoch 51/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 486ms/step - loss: 0.2583 - val_loss: 4.7642
# Epoch 52/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 483ms/step - loss: 0.2406 - val_loss: 4.7990
# Epoch 53/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 485ms/step - loss: 0.2075 - val_loss: 4.8266
# Epoch 54/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 492ms/step - loss: 0.1880 - val_loss: 4.8685
# Epoch 55/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 487ms/step - loss: 0.1732 - val_loss: 4.8787
# Epoch 56/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 484ms/step - loss: 0.1484 - val_loss: 4.9229
# Epoch 57/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 484ms/step - loss: 0.1326 - val_loss: 4.9610
# Epoch 58/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 478ms/step - loss: 0.1141 - val_loss: 4.9957
# Epoch 59/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 486ms/step - loss: 0.0962 - val_loss: 5.0282
# Epoch 60/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 493ms/step - loss: 0.0844 - val_loss: 5.0545
# Epoch 61/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 492ms/step - loss: 0.0748 - val_loss: 5.0789
# Epoch 62/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 490ms/step - loss: 0.0719 - val_loss: 5.0854
# Epoch 63/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 484ms/step - loss: 0.0638 - val_loss: 5.1124
# Epoch 64/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 493ms/step - loss: 0.0547 - val_loss: 5.1405
# Epoch 65/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 493ms/step - loss: 0.0471 - val_loss: 5.1645
# Epoch 66/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 491ms/step - loss: 0.0432 - val_loss: 5.1902
# Epoch 67/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 498ms/step - loss: 0.0358 - val_loss: 5.2081
# Epoch 68/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 494ms/step - loss: 0.0313 - val_loss: 5.2227
# Epoch 69/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 508ms/step - loss: 0.0268 - val_loss: 5.2317
# Epoch 70/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 497ms/step - loss: 0.0246 - val_loss: 5.2706
# Epoch 71/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 502ms/step - loss: 0.0224 - val_loss: 5.2875
# Epoch 72/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 503ms/step - loss: 0.0209 - val_loss: 5.3056
# Epoch 73/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 500ms/step - loss: 0.0194 - val_loss: 5.3121
# Epoch 74/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 490ms/step - loss: 0.0187 - val_loss: 5.3316
# Epoch 75/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 496ms/step - loss: 0.0160 - val_loss: 5.3437
# Epoch 76/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 498ms/step - loss: 0.0344 - val_loss: 5.2000
# Epoch 77/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 492ms/step - loss: 0.2787 - val_loss: 5.1220
# Epoch 78/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 495ms/step - loss: 0.3194 - val_loss: 5.0787
# Epoch 79/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 487ms/step - loss: 0.2462 - val_loss: 5.1021
# Epoch 80/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 484ms/step - loss: 0.1436 - val_loss: 5.1673
# Epoch 81/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 491ms/step - loss: 0.0775 - val_loss: 5.2046
# Epoch 82/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 491ms/step - loss: 0.0410 - val_loss: 5.2355
# Epoch 83/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 489ms/step - loss: 0.0259 - val_loss: 5.2677
# Epoch 84/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 486ms/step - loss: 0.0199 - val_loss: 5.2868
# Epoch 85/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 483ms/step - loss: 0.0159 - val_loss: 5.3103
# Epoch 86/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 484ms/step - loss: 0.0138 - val_loss: 5.3280
# Epoch 87/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 483ms/step - loss: 0.0125 - val_loss: 5.3449
# Epoch 88/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 483ms/step - loss: 0.0116 - val_loss: 5.3602
# Epoch 89/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 480ms/step - loss: 0.0108 - val_loss: 5.3754
# Epoch 90/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 491ms/step - loss: 0.0100 - val_loss: 5.3857
# Epoch 91/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 494ms/step - loss: 0.0095 - val_loss: 5.3986
# Epoch 92/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 474ms/step - loss: 0.0088 - val_loss: 5.4100
# Epoch 93/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 478ms/step - loss: 0.0086 - val_loss: 5.4214
# Epoch 94/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 37s 690ms/step - loss: 0.0081 - val_loss: 5.4311
# Epoch 95/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 714ms/step - loss: 0.0076 - val_loss: 5.4437
# Epoch 96/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 696ms/step - loss: 0.0073 - val_loss: 5.4518
# Epoch 97/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 705ms/step - loss: 0.0071 - val_loss: 5.4628
# Epoch 98/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 708ms/step - loss: 0.0066 - val_loss: 5.4714
# Epoch 99/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 708ms/step - loss: 0.0064 - val_loss: 5.4802
# Epoch 100/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 705ms/step - loss: 0.0061 - val_loss: 5.4891
# Epoch 101/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 703ms/step - loss: 0.0060 - val_loss: 5.4969
# Epoch 102/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 706ms/step - loss: 0.0057 - val_loss: 5.5074
# Epoch 103/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 497ms/step - loss: 0.0055 - val_loss: 5.5146
# Epoch 104/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 25s 470ms/step - loss: 0.0052 - val_loss: 5.5221
# Epoch 105/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 499ms/step - loss: 0.0051 - val_loss: 5.5326
# Epoch 106/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 498ms/step - loss: 0.0049 - val_loss: 5.5391
# Epoch 107/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 494ms/step - loss: 0.0049 - val_loss: 5.5477
# Epoch 108/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 484ms/step - loss: 0.0046 - val_loss: 5.5549
# Epoch 109/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 491ms/step - loss: 0.0045 - val_loss: 5.5602
# Epoch 110/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 486ms/step - loss: 0.0045 - val_loss: 5.5688
# Epoch 111/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 483ms/step - loss: 0.0042 - val_loss: 5.5762
# Epoch 112/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 497ms/step - loss: 0.0041 - val_loss: 5.5834
# Epoch 113/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 511ms/step - loss: 0.0039 - val_loss: 5.5905
# Epoch 114/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 493ms/step - loss: 0.0039 - val_loss: 5.5997
# Epoch 115/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 477ms/step - loss: 0.0038 - val_loss: 5.6051
# Epoch 116/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 483ms/step - loss: 0.0037 - val_loss: 5.6112
# Epoch 117/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 490ms/step - loss: 0.0036 - val_loss: 5.6171
# Epoch 118/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 482ms/step - loss: 0.0034 - val_loss: 5.6257
# Epoch 119/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 489ms/step - loss: 0.0033 - val_loss: 5.6320
# Epoch 120/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 488ms/step - loss: 0.0033 - val_loss: 5.6377
# Epoch 121/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 493ms/step - loss: 0.0032 - val_loss: 5.6436
# Epoch 122/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 494ms/step - loss: 0.0031 - val_loss: 5.6515
# Epoch 123/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 487ms/step - loss: 0.0030 - val_loss: 5.6583
# Epoch 124/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 500ms/step - loss: 0.0030 - val_loss: 5.6631
# Epoch 125/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 503ms/step - loss: 0.0028 - val_loss: 5.6711
# Epoch 126/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 522ms/step - loss: 0.0027 - val_loss: 5.6761
# Epoch 127/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 506ms/step - loss: 0.0027 - val_loss: 5.6842
# Epoch 128/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 494ms/step - loss: 0.0026 - val_loss: 5.6898
# Epoch 129/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 502ms/step - loss: 0.0026 - val_loss: 5.6915
# Epoch 130/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 518ms/step - loss: 0.0025 - val_loss: 5.6988
# Epoch 131/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 496ms/step - loss: 0.0025 - val_loss: 5.7076
# Epoch 132/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 503ms/step - loss: 0.0025 - val_loss: 5.7132
# Epoch 133/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 505ms/step - loss: 0.0027 - val_loss: 5.7013
# Epoch 134/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 29s 528ms/step - loss: 0.2528 - val_loss: 5.2485
# Epoch 135/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 514ms/step - loss: 0.6200 - val_loss: 5.1617
# Epoch 136/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 498ms/step - loss: 0.3387 - val_loss: 5.2318
# Epoch 137/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 496ms/step - loss: 0.1473 - val_loss: 5.2496
# Epoch 138/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 478ms/step - loss: 0.0655 - val_loss: 5.3157
# Epoch 139/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 489ms/step - loss: 0.0310 - val_loss: 5.3545
# Epoch 140/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 503ms/step - loss: 0.0175 - val_loss: 5.3642
# Epoch 141/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 503ms/step - loss: 0.0115 - val_loss: 5.3982
# Epoch 142/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 511ms/step - loss: 0.0092 - val_loss: 5.4140
# Epoch 143/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 501ms/step - loss: 0.0080 - val_loss: 5.4346
# Epoch 144/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 489ms/step - loss: 0.0071 - val_loss: 5.4485
# Epoch 145/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 502ms/step - loss: 0.0066 - val_loss: 5.4623
# Epoch 146/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 486ms/step - loss: 0.0060 - val_loss: 5.4778
# Epoch 147/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 483ms/step - loss: 0.0056 - val_loss: 5.4878
# Epoch 148/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 489ms/step - loss: 0.0052 - val_loss: 5.4975
# Epoch 149/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 492ms/step - loss: 0.0049 - val_loss: 5.5083
# Epoch 150/150
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 496ms/step - loss: 0.0047 - val_loss: 5.5199

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_len_text,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if(sampled_token!='end'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'end'  or len(decoded_sentence.split()) >= (max_len_summary-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_len_text)))
    print("\n")
# Out:
# Review: gluten free sweetener free calls chocolate treat gives indication good thinks would definitely recommend flavor everyone found subscribe save discount get boxes cheaper amazon stores like sunflower sprouts whole foods
# Original summary: chocolate treat
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  chocolate treat
#
#
# Review: healthy dog food good digestion also good small puppies dog eats required amount every feeding
# Original summary: healthy dog food
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  healthy dog food
#
#
# Review: powder made way suggested hot water milk creamy right amount peppermint flavor lumps excellent last drop thrilled see carry amazon know grocery store carried holidays price amazon much less paid
# Original summary: absolutely the best
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  absolutely the best
#
#
# Review: pretty good stuff cannot expect whole lot instant box noodles best brands tried noodles good constancy peanut sauce really tasty well going buy
# Original summary: tatsy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  tatsy
#
#
# Review: well looking another coffee would meet exceed cups using far tasted coffee cups using bought almost packages used ordering boxes soon great coffee regular guy point view
# Original summary: great coffee
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  great coffee
#
#
# Review: idea good liked carbonation refreshing biggest drawback sugar sugar little pepper way much sugar drawback price would buy works almost dollar going pay much would rather buy regular juice store
# Original summary: too much sugar too expensive
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  too much sugar too expensive
#
#
# Review: sonoma vacation sure expect package first bite know think flavors hit yum bit spicy nothing overpowering lots crunchy sweet spicy goodness sold everywhere though still trying find somewhere close live
# Original summary: love these chips
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  love these chips
#
#
# Review: tasted good surprised heard many negative things glutten free bread products would eat choice
# Original summary: yummy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted summary:  yummy
#
#
# Review: love tea makes feel healthy needed christmas new year season used one week soooo feel body needing good detox recommend anyone stomach issues indulges wants feel generally better
# Original summary: love it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  love it
#
#
# Review: love jamaica crazy coffee version flavorful price pretty good sure beats office pot coffee sits burner hours fresh coffee fast
# Original summary: great coffee
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted summary:  great coffee
#
#
# Review: like nothing unique flavor basically saves make home little pricey treat heck
# Original summary: tasted ok bit overpriced tho
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  tasted ok bit overpriced tho
#
#
# Review: wolfgang puck coffee chef reseerve columbian decaf fantastic delicious definitely recommend product anyone wants great cup coffee
# Original summary: wonderful cups
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  wonderful cups
#
#
# Review: things huge love way crystals crunch flavor overpowering subtle lemony flavor favorite good almost everything plenty flavored salt long time buy
# Original summary: big tub salt
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  big tub salt
#
#
# Review: device however drink coffee came across hot cocoa cups took chance incredibly good gives chance share hot drink coffee crowd without boil water milk pack priced well coffee cups well
# Original summary: hot chocolate in seconds
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  hot chocolate in seconds
#
#
# Review: sugar water nasty sugar water product strong fake sugar taste perfectly diet sodas fake sugar products something put finger made stomach curl even waited cool got worse disapointed product expecting
# Original summary: ugh so not what was expecting lt
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  not what expected
#
#
# Review: really great sauce slightly expensive stores great egg rolls dipping sauce many chinese foods also great sauce make chili thai sushi roll
# Original summary: great sauce
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  great sauce
#
#
# Review: licorice good taste daughter gluten free diet loves cherry bites
# Original summary: candy tree organic cherry bites
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  candy tree organic cherry bites
#
#
# Review: buy sale free shipping great value although previously purchased amazon recently bought gnc gold card week free shipping offer buy get free offer deal like breaks less cents per serving
# Original summary: hydrating refreshing great tasting drink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  hydrating refreshing great tasting drink
#
#
# Review: geriatric mini poodle cannot chew biscuits rawhide textures treats soft enough still provide workout gums remaining teeth appreciate fact ingredients domestic manufactured
# Original summary: safe easy to chew tasty for dogs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  dogs love it
#
#
# Review: simple salad seasoning add vinegar oil one packet goyasalad seasoning best salad ever also put ina potato salad marvelous also please give try enjoy
# Original summary: the best salad seasoning ever made
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  the best salad seasoning ever made
#
#
# Review: weird chalky taste hot cocoa cups tasted several far better one say anything larger tastes bit watered definitely purchase rate family downs probably going stick powdered hot cocoa cost effective
# Original summary: great taste the whole family loves
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  great taste the whole family loves
#
#
# Review: percent cocoa semi dark chocolate bar perfect choice people dont usually like dark chocolate tasting nothing likke common dark chocolates like hershey santander quality excellent highly recommend santander chocaltes
# Original summary: perfect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  perfect
#
#
# Review: twizzlers brand licorice much better well known brand get package free good deal black cherry good taste strawberry taste delicate barely
# Original summary: good licorice
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  good licorice
#
#
# Review: energy junkie sure works know taste greatest drink steaz energy drink think get results like products natural others
# Original summary: not sure
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  not sure
#
#
# Review: anyone see theses made avoiding treats china problems lately see country origin
# Original summary: china
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  china
#
#
# Review: cook raw chicken ontop veggies makes slimy mess made snow peas carrots dont like little corn added red pepper flakes heat served ontop rice came wonderful dinner table less mins
# Original summary: delicious
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  delicious
#
#
# Review: using products past years good see main stream companies getting religion product works pancakes waffles come beautifully
# Original summary: trusted name
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  trusted name
#
#
# Review: fish drizzle meat pasta dish note surprisingly best pairings chef tom red meats either chef tom douglas rub love pork rub generous portion chef tom douglas rub love chicken rub
# Original summary: decent spice rub for red meats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  decent spice rub for red meats
#
#
# Review: definitely better pirate booty slightly better baked chips tasty feel almost eat something texture cereal small payoff enjoy chips vinegar ones nasty
# Original summary: but not as good as real chips
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  great coffee
#
#
# Review: used vidalia onion sauce bbq kebob marinade try mixing cubed pork necks medium onions onion sauce mix everything mixing bowl leave covered fridge hours
# Original summary: excellent as bbq kebob marinade
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted summary:  excellent as bbq kebob marinade
#
#
# Review: hot chocolate tastes like hot sugar water pinch coco although even sugary taste weak tainted flavor artificial sweetener sucralose consistency watery bland made cup directed directions box recommend product
# Original summary: tastes like hot sugar water
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  tastes like hot sugar water
#
#
# Review: sugary pour handful eat like toddler expected sugary honey nut grams sugar per serving compared grams honey nut total carbohydrates grams per serving much difference affects body bottom line buy
# Original summary: work for me back to honey nut
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  very good but not perfect
#
#
# Review: well icing even pink lemonade cookie mix bought tried yet taste course lemon reminds bit flavored mix country time drank kid less tangy light refreshing simply loved hope seasonal flavor
# Original summary: tasty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  tasty
#
#
# Review: number units defect always good hear several emails later received return merchandise authorization shipped right back knows one works maybe like blue products look good make strong case buying locally
# Original summary: slight quality control issue
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  slight quality control issue
#
#
# Review: ever ground opposed beans really seem issue ground coffee tend stale quickly bean would suggest using fairly quickly easy ounce bag decaf drinker prefer grind beans would highly recommend brand
# Original summary: had my doubts but am impressed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  had my doubts but am impressed
#
#
# Review: stop like chocolate laced crack anywho product good sad thing shipped stored hot room chocolate melted together partially didnt take much effort take apart sticks great product great price merchant
# Original summary: awsome
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  awsome
#
#
# Review: life tried mahogani caribou coffee run usual type coffee would usually brew drink short even categorize mahogany caribou coffee know far anti depressant uplifting effect previously anticipated drink mahogany caribou
# Original summary: for depression and lifting up your mood
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  disposakup review
#
#
# Review: rancid upon receipt terrible little sugar used something went wrong cannot believe anyone would see final product cans
# Original summary: rotton upon receipt
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  rotton upon receipt
#
#
# Review: use much cooking add oil home made granola cook well high heats well medium low heat health benefits far outweigh vegetable oil canola oils use coconut oils whenever possible flavor
# Original summary: walnut oil
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  walnut oil
#
#
# Review: purchased three pounds arrived well packaged trying find replacement roaster blend good great keep looking
# Original summary: just
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  just
#
#
# Review: read reviewers comment calorie content flavor must high trying wash dish served quite oily also bit grainy texture think month old son finds spinach little difficult digest
# Original summary: grainy and little oily but thick
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  grainy and little oily but thick
#
#
# Review: arent diced mush like bpa would buy reason dont expect diced
# Original summary: ok
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  ok
#
#
# Review: quality good price among chicken soup canidae loves eats cups day would love eat shiny coat allergies sensitive stomach thanks food highly recommend buying somewhere else little cheaper day shipping
# Original summary: great dane loves it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  great dane loves it
#
#
# Review: replacement would shipped asap replacement tube arrived three days later good shape offer pay additional shipping charges declined summary product excellent customer service absolutely first rate highly recommend product seller
# Original summary: real customer service
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  real customer service
#
#
# Review: happened get bad want eat root dirty old root tree enjoy doubt credibility review please feel free read reviews please waste money wife tried could even believe could called truffles
# Original summary: awefull
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  awefull
#
#
# Review: thought yeah bottled water carry work force pay bottle machine turn okay tried another company website nestles region came deer park never tried brand much better turn cloudy boil judge
# Original summary: cloudy means impurities
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  cloudy means impurities
#
#
# Review: flavor strong enough stand density full flavor biscuit also great bagels english muffins toast although tried heard great product use baking would great berry muffin complement game dishes highly recommend
# Original summary: good eat it straight from the jar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  eat it straight
#
#
# Review: good oily crunchy flavorful suspect company bought recipe changed worse better big name brand chip try good health kettle style olive oil chips instead good kettle brand kettle brand chips
# Original summary: used to be my favorite chips
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  used to be my favorite chips
#
#
# Review: know chia seeds really super food brand seems good quality bought kinds look better since eat sprinkled morning cereal expensive buy higher priced brand
# Original summary: good quality
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  good quality
#
#
# Review: rotate newmans nature balance ceasar milans organic dog food dog eat three cannot say better main reason purchase brand charity profits goes way supporting companies give back
# Original summary: great product and great cause
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  great product and great cause
#
#
# Review: works love lundberg eco farmed honey nut rice cake ounce units lundberg eco farmed buttery caramel rice cake ounce units lundberg eco farmed brown rice cake salt free ounce units
# Original summary: love the others not the bars
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted summary:  love the others not the bars
#
#
# Review: bitter drinks like monster took sickly sweet syrupy flavor may leave feeling bit ill try apple cider vinegar tastes fine bit odd tongue soon hits throat flavor fumes overpoweringly awful
# Original summary: it works but not as expected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  it works but not as expected
#
#
# Review: husband jut loves coffee purchased actually loved huge starbucks fan also job would highly recommend product
# Original summary: one of the best coffees
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  one of the best coffees
#
#
# Review: received bottles concentrate paragon mixed exactly specs extremely disappointed four six flavors truly saddened encourage purchase watermelon flavor item returned refund
# Original summary: very weak flavor definately not watermelon
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  very weak flavor definately not watermelon
#
#
# Review: midi mic usb makes audio lag sound professional also people said volume low sound windows turn mic little keep mine also recording program let turn monitoring record ahead buy one
# Original summary: awesome buy for sure
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  awesome buy for sure
#
#
# Review: everything expected except one flaw trouble keeping lever completely machine great product brother excited also gave box hope stores soon ease use great idea clean throw away
# Original summary: roy from columbia ct
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  roy from columbia ct
#
#
# Review: packaged single serve bag buy pack assorted flavors hand whenever feel urge snack unfortunately family discovered good going faster anticipated time order different flavors seasoned right salty spicy love popchips
# Original summary: love popchips
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  love popchips
#
#
# Review: pleased drink sparkling orange tangerine flavored juice found taste good refreshing drink money would rather izze fortified sparkling juice clementine ounce cans brand fortified sparkling juice cleaner taste fewer calories
# Original summary: taste as advertised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  taste as advertised
#
#
# Review: first time ever used agave nectar great keeps blood sugar stable great buy also
# Original summary: great buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  great buy
#
#
# Review: audio technica condenser mic intermittent marginal success tried conversion long run would ahead purchasing usb mic blue icicle probably best converter market necessary give try one make sure return privileges
# Original summary: if it works not always guaranteed solution
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  bit too sweet for my cat
#
#
# Review: melamine baby food milk honey contaminated ciprofloxacin banned soy sauce made human hair spurious drugs exported african countries need good facts quality controls manufacturers chinese producers complying good quality controls
# Original summary: but honestly what goes inside read on
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  what goes what food
#
#
# Review: seen drink much lives bought water chinchillas cannot drink tap water spring water best mad though purchased item week ago cheaper wtf overall love item great water tasted taste great
# Original summary: water for my pets
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  water for my pets
#
#
# Review: best chips ever buy wish stores plain chips fav
# Original summary: very good
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  very good
#
#
# Review: organic tea chinese breakfast yunnan black tea loose leaf bag brew iced tea refrigerator half gallon tea excellent resealable bags work well unopened protect large stash making easier manage subscription
# Original summary: great organic tea at great price
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  great organic tea at great price
#
#
# Review: worst medicinal taste mouth afterwards tic tacs get rid worst within hour yawning drowsy unless really like things taste weird tea flavored cough syrup work buy know bottles big fail
# Original summary: so awful can barely describe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  so awful can barely describe
#
#
# Review: cat grass every month spring find terra cotta pots stores keep two alternate always grass growing loves bought several packs probably need get several batches packet none duds far either
# Original summary: great grass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  great grass
#
#
# Review: coffee says medium roast actually little stronger loved become favorite want coffee caffeine one also wolfgang puck breakfast bed great strong
# Original summary: wolfgand puck rodeo drive cup
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  wolfgand puck rodeo drive cup
#
#
# Review: nice productfull quality items cheap candies like baskets
# Original summary: easter basket
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  easter basket
#
#
# Review: great deal great transaction finally affordable way indulge chocolate craving definitely buy
# Original summary: mix chocolate mocha ounce tins pack of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  chocolate tastes great
#
#
# Review: review much buying brand irish wolfhound years still loves good large breed dog dog food good choice healthy food
# Original summary: quality for good price
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted summary:  quality for good price
#
#
# Review: essential muscles hormones enzymes antibodies structural protective tissues also beef free range anad range fed hormones antibiotics evidence clear good quality food dog loves love buy newman products royalties charity
# Original summary: no hormones or antibiotics in the meat
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  the rolls
#
#
# Review: care licorice husband thinks best licorice ever loves stuff also given two friends licorice lovers say delicious
# Original summary: likes it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  likes it
#
#
# Review: buying milk hot chocolate months one best even got laws hooked granddaughters absolutely love great price great product
# Original summary: amazon nut
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  amazon nut
#
#
# Review: great mixed belgium waffles family thinks best must try order amazon let friends know use product
# Original summary: great stuff
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  great stuff
#
#
# Review: flavor salt vinegar sour like type cheddar sour cream onion varieties good favorites good deal subscribe save chips delivered door individually bagged ready take lunch convenient nothing bad say popchips
# Original summary: pop chips yum
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  pop chips yum
#
#
# Review: awesome dust gave cake pops great sparkle used white purple candy melts would recommend anyone
# Original summary: sparkles
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  sparkles
#
#
# Review: brownies good flax seed texture real turn minimize added little whole wheat flour splenda cocoa big improvement guests never complained
# Original summary: good healthy dessert but needs work
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  good healthy dessert but needs work
#
#
# Review: grass cannot return aready cracked open kit grew grass one three seed kits grass probably fne bunny owner want bunny owners know grass like wheatgrass stores jut surprised disappointed like
# Original summary: not like the wheatgrass in stores
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted summary:  not like the wheatgrass in stores
#
#
# Review: taste much superior regular freeze dried get supermarket would bet enjoy taste much
# Original summary: colcafe greaatt coffee
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  colcafe greaatt coffee
#
#
# Review: arrive broken ingredients per label water organic apples organic carrots organic brown rice organic lentils organic canola oil calories protein vitamin vitamin calcium iron informed daily intake percentage based adult
# Original summary: with the subscription the price is fair
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  love the subscription love it
#
#
# Review: pleased recent purchase meyeberg powdered goat milk shopped around locally far best price per could find delivered promised
# Original summary: great product and timely delivery
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  great product and timely delivery
#
#
# Review: dogs love ran recently counter sniffing trying find service dog maintain weight perfect
# Original summary: love these
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted summary:  love these
#
#
# Review: even vitamin water believe say must consume quickly need spoon turn jello consistency quick actually bad either bulk calorie pudding snack stirring teaspoon many ways get creative chia seeds enjoy
# Original summary: great but eat fast
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  great but eat fast
#
#
# Review: know ordering biscuit crumbs exactly received lousy product amazon fault shipping expires products never order food amazon com ever
# Original summary: new amazon com sells biscuit crumbs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  new amazon com sells biscuit crumbs
#
#
# Review: good coffee flavor get every months great think getting coffee comes door
# Original summary: senseo paris french vanilla coffee pods
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  senseo paris french vanilla coffee pods
#
#
# Review: prepackaged cups use brand choice fraction cost reviewers noted sometimes cup gets stuck handle raises trying remove used cup simply pull never lid fall still mess definitely continue use product
# Original summary: love disposakups
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  love disposakups
#
#
# Review: brewing messy empty wash use disposakups work much better well pre filled cups leaks mess use want throwing filter rinsing using fresh filter great product highly recommend love coffee machine
# Original summary: disposable is great
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  disposable is great
#
#
# Review: little packet makes whole pan full sweet corn goodness side dish dessert decide easy prepare delicious table
# Original summary: fiesta sweet corn cake
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  fiesta sweet corn cake
#
#
# Review: service great meant buy swiss chalet chicken sauce marinade love sauce yet try marinade
# Original summary: swiss chalet
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted summary:  swiss chalet
#
#
# Review: two four year old enjoy cookies good tastingvery convenient packaging great stuffing glove compartment emergencies right size kidsno bad stuffno complaints
# Original summary: great snack for toddlers
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  great snack for toddlers
#
#
# Review: could give food zero would tried dogs loved runs days horrible smelled bad would never get
# Original summary: horrible and gave the dogs the runs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  our dogs love it
#
#
# Review: tourangelle makes really good oils like company alot try sesame oil
# Original summary: really good
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  really good
#
#
# Review: love mulling pack big bags love crunch intense curry flavor seediness fact gluten free one original savory snacks find hard need good teeth love substantial curry flavor kind indian tasting
# Original summary: like an indian meal in stick
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted summary:  like an indian meal in stick
#
#
# Review: orange tangerine flavor tried watermelon strawberry like much wanted give company another shot prefer orange tangerine nice citrus flavor carbonated fizzy tongue sensation give better watermelon strawberry ice drank whole
# Original summary: fizzy citrus
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  fizzy citrus
#
#
# Review: really great snack hiking baseball game son enjoy taking road trip hold till find good restaurant
# Original summary: great flavor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  great flavor
#
#
# Review: simply lack lip smacking satisfaction disassembled oreo digested pieces whole point ounce bag wafers tout calorie packs fine idea weight watchers advocates rest watching weight feel satisfied finishing one pack
# Original summary: if deception helps monitor calories why not
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted summary:  throw up on the calories
#
#
# Review: aroma pleasant flavor nice smooth weak really wanted like one available subscribe save cannot recommend even making smaller cups weak going stick newman organics extra bold cup
# Original summary: nice flavor but very weak
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  nice flavor but very weak
#
#
# Review: favorite kcup would describe medium dark creamy rich consistent lot cups seem acidic really glad found one
# Original summary: love this creamy coffee
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  love this creamy coffee
#
#
# Review: many uses even used tea powder make lovely hot tea use one packet per ounces hot water brewing required tea dissolves easily hot ice cold water highly recommend rebecca review
# Original summary: very reasonably priced and delicious
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary:  very reasonably priced and delicious
#
#
# Review: purchased two liters looking oil put salads bread etc something strong flavor olive oil good cooking little flavor
# Original summary: good for cooking
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted summary:  good for cooking

# %%
from keras.saving import save_model
save_model(model,'./summa.keras')

# %%
import pickle
with open("input_tokenizer.pkl", 'wb') as file:
    pickle.dump(x_tokenizer, file)
with open("summ_tokenizer.pkl", 'wb') as file:
    pickle.dump(y_tokenizer, file)

# %%
from keras.saving import load_model
from attention import AttentionLayer
model = load_model('./summa.keras', {'AttentionLayer' : AttentionLayer})

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 30)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 30, 300)   │  5,073,000 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 30, 300), │    721,200 │ embedding[0][0]   │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 30, 300), │    721,200 │ lstm[0][0]        │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 300) │  1,275,000 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 30, 300), │    721,200 │ lstm_1[0][0]      │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    721,200 │ embedding_1[0][0… │
# │                     │ 300), (None,      │            │ lstm_2[0][1],     │
# │                     │ 300), (None,      │            │ lstm_2[0][2]      │
# │                     │ 300)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_layer     │ [(None, None,     │    180,300 │ lstm_2[0][0],     │
# │ (AttentionLayer)    │ 300), (None,      │            │ lstm_3[0][0]      │
# │                     │ None, 30)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_layer        │ (None, None, 600) │          0 │ lstm_3[0][0],     │
# │ (Concatenate)       │                   │            │ attention_layer[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, None,      │  2,554,250 │ concat_layer[0][… │
# │ (TimeDistributed)   │ 4250)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 35,902,052 (136.96 MB)
#  Trainable params: 11,967,350 (45.65 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 23,934,702 (91.30 MB)
